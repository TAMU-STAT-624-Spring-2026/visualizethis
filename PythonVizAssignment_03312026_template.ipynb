# %% [markdown]
# # Group Assignment: Data Preparation and Visualization (Product Portfolio Edition)

# %% [markdown]
# ## 1. Group members
#
# <Add your group members' first and last names here>
#
# ***

# %% [markdown]
# ## 2. Contribution report
#
# After completing the assignment, please answer the following questions **as a group** by adding your answers within this markdown block.
#
# 1. In a few sentences, describe each group member's individual contributions to the submission. Be as specific as possible (e.g. coordinated group efforts, specific problems answered, specific problems reviewed/revised, sections of the submission written, etc.).
#
#     < Add your responses here>
#
#
# 2. In a few sentences, describe what was learned in completing this assignment. In particular, describe what was learned through the **specific individual contributions** mentioned above.
#
#     < Add your responses here>
#
# ***

# %% [markdown]
# ## 3. Assignment
#
# ### Instructions:
# You will be presented with a scenario and will need to utilize your SQL and Python skills to complete this assignment successfully.
#
# Put this `.ipynb` file in the `jupyter_notebooks` folder in your Docker SQLPython Container directory. Then you will be able to connect to the database and run your code without issue.
#
# Each group will submit two files:
# 1. A single Jupyter Notebook (`.ipynb`). **You must run all cells before submitting.** This notebook should have all of the relevant visualizations and output displayed properly. We will restart and run all of the code from this notebook, which should not produce any errors.
# 2. A PDF version (`.pdf`) of the Jupyter Notebook. This PDF should have all of the relevant visualizations and output displayed properly.

# %%
# run this code first to connect to the database and verify the connection is working
## DO NOT MODIFY THIS CODE BLOCK
## If you have placed this notebook in the jupyter_notebooks folder properly,
## this block should return the first two rows of the products table

from sqlalchemy import create_engine, text
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from matplotlib.ticker import StrMethodFormatter
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib inline
sns.set_theme(style="whitegrid", context="talk")

cnxn_string = ("postgresql+psycopg2://{username}:{pswd}"
              "@{host}:{port}/{database}")
print(cnxn_string)

engine = create_engine(cnxn_string.format(
    username="postgres",
    pswd="behappy",
    host="postgres",
    port=5432,
    database="sqlda"))

with engine.connect() as conn:
    conn.execute(text("SELECT * FROM products LIMIT 2;"))

# %% [markdown]
# ## Scenario
#
# You are a team of highly successful data scientists at a transportation products company that sells both automobiles and scooters. Your manager needs summary tables and visualizations for the next shareholder meeting and has sent the following email describing what she needs.
#
# ***
# From: importantboss@mobilityproductsco.com
#
# To: datascienceteam@mobilityproductsco.com
#
# Subject: Product portfolio request for shareholder meeting
#
# For our next shareholder meeting, we need a clearer story about product demand and sales performance. Please send me information to address the following items along with your thoughts.
#
# 1. Which product models have been the most popular and least popular since January 1, 2016?
# 2. How have our product lines trended historically over time?
# 3. During 2018, how did weekly sales compare with management's weekly sales targets for each product line?
#
# Thank you!
#
# - Important Boss
#
# ***

# %% [markdown]
# Your team promptly comes up with the following plan.

# %% [markdown]
# ## Part 1: Visualizing the popularity of products
#
# ### 2.1 SELECT query
# Write a `SELECT` query that returns the total number of units sold for each product `model` from January 1, 2016 to now. The table should have two columns, `model` and `units_sold`, with one row for each distinct model ordered by `units_sold` in **descending** order. Join the `sales` and `products` tables by `product_id`. Use the `model` exactly as it appears in the `products` table, even if that model appears in multiple model years.
#
# ### 2.2 Create dataframe
# Use SQLAlchemy to execute the query and store the results in a pandas dataframe called `sales_by_model`.
#
# ### 2.3 Display top 5
# Display the rows in `sales_by_model` corresponding to the 5 models with the **largest** values of `units_sold` in **descending** order.
#
# ### 2.4 Display bottom 5
# Display the rows in `sales_by_model` corresponding to the 5 models with the **smallest** values of `units_sold` in **ascending** order.
#
# ### 2.5 Visualization(s)
# Visualize model popularity for the top and bottom performing models discovered in 2.3 and 2.4. You may use more than one visualization. These should be **presentation ready** (e.g. appropriate and complete titles and axis labels, no overlapping labels, readable model names, clear indication that the measure is units sold, and the date range is communicated clearly).
#
# Include the code needed for each component of Part 1 in the appropriate code block below.

# %%
# 2.1

# %%
# 2.2 create dataframe

# %%
# 2.3 display top 5 most popular models

# %%
# 2.4 display bottom 5 least popular models

# %%
# 2.5 visualize product popularity

# %% [markdown]
# ## Part 2: Visualizing product line trends
#
# Create a table and visualization of historical cumulative sales amounts by product line from January 1, 2016 to now.
#
# ### 3.1 SELECT query
# Write a `SELECT` query that returns three columns: `product_type`, `sales_transaction_date`, and `cumulative_sales`. `cumulative_sales` should represent the cumulative sales amount from January 1, 2016 to the `sales_transaction_date` for the product line identified by `product_type`. There should be a row for each distinct combination of `product_type` and `sales_transaction_date` in the `sales` table. Join `sales` to `products` by `product_id`. A window function will be helpful here.
#
# ### 3.2 Create dataframe
# Use SQLAlchemy to execute the query and store the results in a pandas dataframe called `cumulative_sales_by_productline`.
#
# ### 3.3 Visualization
# Appropriately visualize historical cumulative sales by product line across sales transaction dates **in a single plot**. The visualization should be **presentation ready** (e.g. appropriate and complete title and legend/axis labels, readable date axis, clearly labeled product lines, formatted sales amounts, and unnecessary or distracting chart elements removed).

# %%
# 3.1

# %%
# 3.2

# %%
# 3.3

# %% [markdown]
# ## Part 3: Weekly sales targets
#
# Create a table and visualization to compare weekly sales amounts with management's weekly sales targets during calendar year 2018. Use sales made on or after January 1, 2018 and before January 1, 2019. Management has set a weekly sales target of `$1,300,000` for the `automobile` product line and `$95,000` for the `scooter` product line.
#
# ### 4.1 SELECT query
# Write a `SELECT` query that returns the following five columns: `sales_week`, `product_type`, `weekly_sales`, `weekly_target`, and `target_status`. `sales_week` should be the week associated with `sales_transaction_date` (for example, by using `DATE_TRUNC('week', sales_transaction_date)`). `weekly_sales` should be the total sales amount for that week and product line. `weekly_target` should be a derived value equal to the target for that product line. `target_status` should be a derived categorical field that takes the value `'Met or exceeded target'` when `weekly_sales` is greater than or equal to `weekly_target` and `'Below target'` otherwise. There should be one row for each distinct combination of `sales_week` and `product_type`.
#
# ### 4.2 Create dataframe
# Use SQLAlchemy to execute the query and store the results in a pandas dataframe called `weekly_sales_targets`.
#
# ### 4.3 Visualization
# Appropriately visualize weekly sales performance against the weekly target for each product line. You may use one figure with multiple panels or another equally clear layout. The visualization should be **presentation ready** (e.g. appropriate and complete titles and axis labels, clear distinction between actual sales and the target, readable weekly date labels, well-labeled product lines, and distracting features removed).

# %%
# 4.1 select query

# %%
# 4.2 create dataframe

# %%
# 4.3 visualization

# %% [markdown]
# ## Part 4: Takeaways from the analysis
#
# Provide your thoughts about the analysis above by answering the following questions in the blank markdown cells provided below. No code should be run for this section.
#
# ### 5.1 Hypotheses for most/least popular models
# What are some potential hypotheses as to why the most popular and least popular models have the sales counts observed in Part 1? Describe how you would test your hypotheses in further analysis. Do not conduct any additional analyses or write any more queries; just describe your ideas in words.
#
# ### 5.2 Characterize historical performance
# How would you characterize the historical performance of the product lines visualized in Part 2 (e.g. growing, plateauing, accelerating, volatile, etc.)? Describe the trends in relative performance over time and cite specific elements of the visualization created in Part 2 to support your claims. Specify any additional factors you would want to consider that could influence your performance assessment.
#
# ### 5.3 Characterize weekly sales
# How would you characterize weekly sales target performance in Part 3? Which product lines met or missed their targets more consistently? Were there stretches of time where performance clearly improved or deteriorated? Be specific and cite specific elements of the visualization created in Part 3 to support your claims.

# %% [markdown]
# ### Part 4 Responses

# %% [markdown]
# For each of the following questions, answer with as much precision and clarity as you can. Refer back to the tables and plots you created to support your answers as needed. Do **not** write code for this section.

# %% [markdown]
# 1. (Part 1) What are some potential hypotheses as to why the most popular and least popular models have the sales counts observed? Describe how you would test your hypotheses in further analysis. Do not conduct any additional analyses or write any more queries; just describe your ideas in words.

# %% [markdown]
# 2. (Part 2) How would you characterize the historical performance of the product lines visualized in Part 2 (e.g. growing, plateauing, accelerating, volatile, etc.)? Describe the trends in relative performance over time and cite specific elements of the visualization created in Part 2 to support your claims. Specify any additional factors you would want to consider that could influence your performance assessment.

# %% [markdown]
# 3. (Part 3) How would you characterize weekly sales target performance in Part 3? Which product lines met or missed their targets more consistently? Were there stretches of time where performance clearly improved or deteriorated? Be specific and cite specific elements of the visualization created in Part 3 to support your claims.
